# %% [markdown]
# # Random Variables and Expectation

# %% [markdown]
# ## Motivation
#
# In many problems, outcomes are uncertain.<br>
# However, mathematics operates on numbers, not on abstract outcomes.
#
# To apply mathematical tools to uncertainty,<br> we need a way to represent
# uncertain outcomes numerically in a consistent and structured manner.
#
# Random variables provide this bridge between uncertainty and mathematics.
